# %%
from transformers import DistilBertTokenizer

# %%
# 1. Load pre-trained tokenizer
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# %%
text = "DistilBERT is a fast, light model!"

# %%
# 2. Tokenize and prepare input
tokens = tokenizer.tokenize(text)
input_ids = tokenizer.encode(text)

tokens, input_ids
# Out:
# (['di', '##sti', '##lbert', 'is', 'a', 'fast', ',', 'light', 'model', '!'],
#  [101, 4487, 16643, 23373, 2003, 1037, 3435, 1010, 2422, 2944, 999, 102])

# %% [markdown]
# And you can downlod  [wordpiece vocab.txt](https://huggingface.co/distilbert/distilbert-base-uncased/blob/main/vocab.txt)

# %%
# 3. load wordpiece vocab 

vocab = tokenizer.get_vocab()

vocab['di']
# Out:
# 4487
