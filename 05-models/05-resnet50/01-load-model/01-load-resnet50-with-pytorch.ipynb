# %%
import torch
from torchvision import models, transforms

# %%
# 1. Load the model with the best available weights (ImageNet-1K V2)
weights = models.ResNet50_Weights.DEFAULT
model = models.resnet50(weights=weights)
