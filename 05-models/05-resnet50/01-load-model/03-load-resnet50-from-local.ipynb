# %%
from transformers import ResNetForImageClassification

# It will automatically pick 'model.safetensors' or 'pytorch_model.bin'
model = ResNetForImageClassification.from_pretrained("./resnet50_files")
