# %%
# First, install: pip install huggingface_hub
from huggingface_hub import snapshot_download

# Downloads the entire repository to a local folder
snapshot_download(repo_id="microsoft/resnet-50", local_dir="./resnet50_files")
# Out:
# Fetching 8 files: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:19<00:00,  2.46s/it]
# '/Users/karlxu/Workspace/github/xuyuji9000/machine-learning-playground/05-models/05-resnet50/resnet50_files'
