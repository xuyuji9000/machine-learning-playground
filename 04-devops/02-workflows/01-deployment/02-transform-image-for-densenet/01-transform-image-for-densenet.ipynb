# %%
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# define custom transform function
my_transforms = transforms.Compose([
	transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225])
])

# %%
image_path = './images/Koalainputimage.jpg'
image = Image.open(image_path)

image_np = np.array(image)
print(f'numpy array shape of the image: {image_np.shape}')
# Out:
# numpy array shape of the image: (768, 1024, 3)

# %%
tensor = my_transforms(image)
tensor.shape
# Out:
# torch.Size([3, 224, 224])

# %%
transformed_image = tensor.numpy().transpose(1, 2, 0)

# display the normalized image
plt.imshow(transformed_image)
plt.xticks([])
plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.64].
# ([], [])
