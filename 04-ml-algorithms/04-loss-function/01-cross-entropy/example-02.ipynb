# %% [markdown]
# target distribution: `[1, 0, 0]`
#
# predicted distribution: `[0.067, 0.821, 0.111]`

# %%
import numpy as np
-1*np.log(0.067), - 0*np.log(0.821), - 0*np.log(0.111)
# Out:
# (np.float64(2.703062659591171), np.float64(-0.0), np.float64(-0.0))

# %%
0.2703+0+0
# Out:
# 0.2703
